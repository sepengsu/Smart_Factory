# %% [markdown]
# 1. 데이터 종류
#
# c1_001.csv -> c1 tool에 관한 데이터
#
# c1_wear.csv-> 얼마나 깍여있냐?

# %%
data = pd.read_csv('./archive/c6/c6_wear.csv')
data.shape
# Out:
# (315, 4)

# %%
data
# Out:
#      cut     flute_1     flute_2     flute_3
# 0      1   32.317114   48.892617   37.720825
# 1      2   37.914879   49.570815   37.720825
# 2      3   43.087910   50.302867   37.720825
# 3      4   47.859072   51.083652   37.849851
# 4      5   52.250329   51.908288   38.172665
# ..   ...         ...         ...         ...
# 310  311  170.981042  161.824508  155.546719
# 311  312  171.411854  162.517989  156.189184
# 312  313  171.839631  163.218075  156.844309
# 313  314  172.264561  163.924726  157.512083
# 314  315  172.686837  164.637900  158.192482
#
# [315 rows x 4 columns]

# %% [markdown]
# ### EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# CSV 파일 읽기 (파일명은 'data.csv'로 가정)

# %%
# 각 컬럼별 시계열 그래프 그리기
df.plot(subplots=True, layout=(4, 2), figsize=(15, 10), title="Time Series Plot for Each Column")
plt.tight_layout()
plt.show()

# %%
# 각 컬럼별 히스토그램 그리기
df.hist(figsize=(15, 10))
plt.tight_layout()
plt.show()

# %%
# 각 컬럼별 박스플롯 그리기
plt.figure(figsize=(15, 10))
df.boxplot()
plt.tight_layout()
plt.show()

# %%
# 상관 행렬 계산 및 히트맵 그리기
correlation_matrix = df.corr()
plt.figure(figsize=(10, 7))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# %%
# Pairplot 그리기
sns.pairplot(df)
plt.suptitle("Pairplot of Variables", y=1.02)
plt.show()
# Out:
# c:\Users\na062\anaconda3\envs\python10\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
